# %% [markdown]
# ## Notebook to investigate the trend and accelleration of tide gauge data

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/Wind_contribution/Analysis/code')

import import_data as imprt

# %%
# Open data file
tg_data_era5 = imprt.import_obs_slh_data()
tg_data_20cr = imprt.import_obs_slh_data(data_type = '20cr')

# %%
tg_data_era5.plot(figsize = (9,3))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
tg_data_20cr.plot(figsize = (9,3))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
# Increase over different time periods
tg_data_20cr.loc[1901]
# Out:
# Vlissingen        -19.824980
# Hoek v. Holland   -12.743320
# Den Helder        -12.898763
# Delfzijl          -11.736708
# Harlingen         -10.705110
# IJmuiden          -12.352436
# Average           -13.376886
# Name: 1901, dtype: float64

# %%
import xarray as xr

# %%
data = xr.open_dataset('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Data/cmip6/Wind/wind_annual_historical.nc')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 43, time: 165, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 ...
#     v2       (model, time, lat, lon) float64 ...
# Attributes:
#     emission_scenario:  historical
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:52
