# %% [markdown]
# # Import CMIP6 sea level data and store as a netcdf file
#
# The first part of the notebook has the aim to process cmip6 sea level data and save it as one dataset that is ready to be used for the regression analysis.
#
# Coordinates are changed, names are changed, time periods and areas are changed.

# %%
# %load_ext autoreload
# %autoreload 2

from code import prepare_data as prep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Historic

# %%
slh_data_hist = prep.prep_slh_data_cmip6()
# Out:
# did the test work?

# %%
slh_data_hist
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 51, time: 165)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 1.85e+03 1.852e+03 1.852e+03 ... 2.014e+03 2.014e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 dask.array<chunksize=(1, 165, 15, 10), meta=np.ndarray>
# Attributes:
#     emission_scenario:  historical
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 10:13

# %% [markdown]
# #### piControl

# %%
slh_data_pico = prep.prep_slh_data_cmip6(data_type = 'piControl')

# %%
slh_data_pico
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 52, time: 5850)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 1.5 2.5 3.5 4.5 ... 6.198e+03 6.2e+03 6.2e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 nan nan nan nan ... nan nan nan nan
# Attributes:
#     emission_scenario:  piControl
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 12:47

# %% [markdown]
# #### SSP119

# %%
slh_data_119 = prep.prep_slh_data_cmip6(data_type = 'ssp119')

# %%
slh_data_119
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 15, time: 86)
# Coordinates:
#   * model    (model) object 'CAMS-CSM1-0' 'CNRM-ESM2-1' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 15, 10), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp119
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 16:49

# %% [markdown]
# #### SSP126

# %%
slh_data_126 = prep.prep_slh_data_cmip6(data_type = 'ssp126')

# %%
slh_data_126
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 35, time: 86)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 15, 10), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp126
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 17:12

# %% [markdown]
# #### SSP245

# %%
slh_data_245 = prep.prep_slh_data_cmip6(data_type = 'ssp245')

# %%
slh_data_245
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 35, time: 86)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 15, 10), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp245
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 22:11

# %% [markdown]
# #### SSP370

# %%
slh_data_370 = prep.prep_slh_data_cmip6(data_type = 'ssp370')

# %%
slh_data_370
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 34, time: 86)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 15, 10), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp370
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 22:43

# %% [markdown]
# #### SSP585

# %%
slh_data_585 = prep.prep_slh_data_cmip6(data_type = 'ssp585')

# %%
slh_data_585
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 15, lon: 10, model: 38, time: 86)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 45.5 46.5 47.5 48.5 49.5 ... 55.5 56.5 57.5 58.5 59.5
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
# Data variables:
#     zos      (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 15, 10), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp585
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-23 22:42

# %% [markdown]
# # Import CMIP6 wind data and store as a netcdf file
#
# This second part of the notebook has the aim to process cmip6 wind data and save it as one dataset that is ready to be used for the regression analysis.

# %%
# %load_ext autoreload
# %autoreload 2

from code import prepare_data as prep

# %% [markdown]
# #### Historic

# %%
wind_data_hist, wind_data_hist_vel = prep.prep_wind_data_cmip6()

# %%
wind_data_hist
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 50, lon: 70, model: 43, time: 165)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 1.85e+03 1.852e+03 1.852e+03 ... 2.014e+03 2.014e+03
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 165, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 165, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  historical
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:52

# %% [markdown]
# #### piControl

# %%
wind_data_pico, wind_data_pico_vel = prep.prep_wind_data_cmip6(data_type = 'piControl')

# %%
wind_data_pico

# %% [markdown]
# #### SSP119

# %%
wind_data_119, wind_data_119_vel = prep.prep_wind_data_cmip6(data_type = 'ssp119')

# %%
wind_data_119
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 50, lon: 70, model: 14, time: 86)
# Coordinates:
#   * model    (model) object 'CAMS-CSM1-0' 'CNRM-ESM2-1' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp119
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:53

# %% [markdown]
# #### SSP126

# %%
wind_data_126, wind_data_126_vel = prep.prep_wind_data_cmip6(data_type = 'ssp126')

# %%
wind_data_126
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 50, lon: 70, model: 34, time: 86)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp126
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:53

# %% [markdown]
# #### SSP245

# %%
wind_data_245 = prep.prep_wind_data_cmip6(data_type = 'ssp245')

# %%
wind_data_245
# Out:
# (<xarray.Dataset>
#  Dimensions:  (lat: 50, lon: 70, model: 34, time: 86)
#  Coordinates:
#    * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#    * time     (time) float64 2.016e+03 2.016e+03 2.018e+03 ... 2.1e+03 2.1e+03
#    * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#    * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
#  Data variables:
#      u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#      v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#  Attributes:
#      emission_scenario:  ssp245
#      source_file:        This NetCDF file was built from PreparePlaneVariables.py
#      creation_date:      2021-09-24 10:23,
#  <xarray.Dataset>
#  Dimensions:  (lat: 50, lon: 70, model: 34, time: 86)
#  Coordinates:
#    * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
# ...

# %% [markdown]
# #### SSP370

# %%
wind_data_370, wind_data_370_vel = prep.prep_wind_data_cmip6(data_type = 'ssp370')

# %%
wind_data_370

# %% [markdown]
# #### SSP585

# %%
wind_data_585, wind_data_585_vel = prep.prep_wind_data_cmip6(data_type = 'ssp585')

# %%
wind_data_585

# %% [markdown]
# # Import CMIP6 wind data and store as a netcdf file
#
# This second part of the notebook has the aim to process cmip6 wind data and save it as one dataset that is ready to be used for the regression analysis.

# %%
# %load_ext autoreload
# %autoreload 2

from code import prepare_data as prep

# %%
# Import necessary packages
import xarray as xr # used for analysing netcdf format data
import numpy as np
import pandas as pd
import glob as gb


"""
Practical functions
--------------------------


"""


# Function to save data as NETCDF4 file
def save_nc_data(data, folder, variable, name): 
    """
    For folder choose ['observations', 'cmip6'], for variable choose ['Wind', 'SLH', 'Pressure', 'SST']
    
    """
    data.to_netcdf(f"/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Data/{folder}/{variable}/{name}.nc")
    

    
def prep_pres_data_cmip6(data_type = 'historical'):
    """
    Function to prepare the cmip6 pressure data for the analysis
    
    For data_type choose ['historical', 'piControl', 'ssp119', 'ssp126', 'ssp245', 'ssp370', 'ssp585']
    
    """
    
    
    # Define path to cmip6 data
    path = '/Volumes/Iris 300 GB/CMIP6'
    
    
    
    
    if data_type == 'piControl':
        
        
        
        # Create empty list to save files
        piControl = []

        # Loop over all files in directory
        for file in gb.glob(f'{path}/cmip6_ps_piControl/*'):
            
            
            # Open data file
            data = xr.open_dataset(file)
    
    
            # Select area
            data = data.where((data.lat > 0) & (data.lat < 90) & (data.lon > -90) & (data.lon < 90), drop=True)
    
            
            # Add file to list
            piControl.append(data)
            
        # Merge all files to one dataset 
        dataset_annual = xr.merge(piControl, combine_attrs='override')
        
    
    
    
    else: 
        
        
        # Open data files as dataset
        dataset_annual = xr.open_mfdataset(f'{path}/cmip6_ps_{data_type}/cmip6_ps_{data_type}_*.nc')
    
    
        # Select area
        dataset_annual = dataset_annual.where((dataset_annual.lat > 0) & (dataset_annual.lat < 90) & (dataset_annual.lon > -90) & (dataset_annual.lon < 90), drop=True)
    
    
    # Change coordinate and variable names
    dataset_annual = dataset_annual.rename({"CorrectedReggrided_ps":"ps"})
    
    
    # Save annual data as netcdf4           
    save_nc_data(dataset_annual, 'cmip6', 'Pressure', f'pressure_annual_{data_type}')    
    
    
    
    
    return dataset_annual

# %% [markdown]
# #### Historic

# %%
pres_data_hist = prep.prep_pres_data_cmip6()

# %%
pres_data_hist

# %% [markdown]
# #### piControl

# %%
#pres_data_pico = prep.prep_pres_data_cmip6(data_type = 'piControl')

# %%
#pres_data_pico

# %% [markdown]
# #### SSP119

# %%
pres_data_119 = prep.prep_pres_data_cmip6(data_type = 'ssp119')

# %%
pres_data_119

# %% [markdown]
# #### SSP126

# %%
pres_data_126 = prep.prep_pres_data_cmip6(data_type = 'ssp126')

# %%
pres_data_126

# %% [markdown]
# #### SSP245

# %%
pres_data_245 = prep.prep_pres_data_cmip6(data_type = 'ssp245')

# %%
pres_data_245

# %% [markdown]
# #### SSP370

# %%
pres_data_370 = prep.prep_pres_data_cmip6(data_type = 'ssp370')

# %%
pres_data_370

# %% [markdown]
# #### SSP585

# %%
pres_data_585 = prep.prep_pres_data_cmip6(data_type = 'ssp585')

# %%
pres_data_585
