# %% [markdown]
# # Import CMIP6 sea level data and store as a netcdf file
#
# The first part of the notebook has the aim to process cmip6 sea level data and save it as one dataset that is ready to be used for the regression analysis.
#
# Coordinates are changed, names are changed, time periods and areas are changed.
#
# In this notebook, functions are used from: '/code/prepare_data.py'

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/Wind_contribution/Data preparation/code')

import prepare_data as prep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Historic

# %%
slh_data_hist = prep.prep_slh_data_cmip6()

# %%
slh_data_hist
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 51, time: 165)>
# dask.array<concatenate, shape=(7, 51, 165), dtype=float64, chunksize=(1, 1, 165), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 1986-2005, including 20...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1
#     branching_method:   unsing_branching_time
#     detrending_order:   1

# %% [markdown]
# #### piControl

# %%
slh_data_pico = prep.prep_slh_data_cmip6(data_type = 'piControl')

# %%
slh_data_pico
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 52, time: 2000)>
# array([[[-2.75330094, -5.79304815,  0.0637607 , ...,         nan,
#                  nan,         nan],
#         [-1.05378563,  1.2137263 , -1.63955194, ...,         nan,
#                  nan,         nan],
#         [ 4.28717627,  3.90435436,  4.06483787, ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 3.80809187,  1.57484363,  2.07364746, ...,         nan,
#                  nan,         nan],
#         [ 1.34818112,  1.48651925,  2.32273965, ...,         nan,
#                  nan,         nan],
#         [-1.19409549,  0.43950862,  0.99069744, ...,         nan,
#                  nan,         nan]],
#
#        [[-2.75330094, -5.79304815,  0.0637607 , ...,         nan,
#                  nan,         nan],
#         [-1.05378563,  1.2137263 , -1.63955194, ...,         nan,
#                  nan,         nan],
#         [ 4.28717627,  3.90435436,  4.06483787, ...,         nan,
#                  nan,         nan],
# ...
#         [-0.1580558 , -5.01567766,  3.18990364, ...,         nan,
#                  nan,         nan],
#         [-0.68593146, -1.0235325 ,  3.81329541, ...,         nan,
#                  nan,         nan],
#         [-3.11846892,  0.37688494,  2.52094754, ...,         nan,
#                  nan,         nan]],
#
#        [[-3.4256274 , -6.22121817, -0.17818551, ...,         nan,
#                  nan,         nan],
#         [-1.75003456,  2.59955361, -2.13757079, ...,         nan,
#                  nan,         nan],
#         [ 4.85969854,  3.44306569,  2.92083562, ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 1.25968784, -3.02550098,  2.59617421, ...,         nan,
#                  nan,         nan],
#         [-0.13462069, -0.05841888,  3.30797754, ...,         nan,
#                  nan,         nan],
#         [-2.12642547,  0.30189362,  1.62766018, ...,         nan,
#                  nan,         nan]]])
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) float64 0.0 1.0 2.0 3.0 ... 1.997e+03 1.998e+03 1.999e+03
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 950-969, including 969,...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1

# %% [markdown]
# #### SSP119

# %%
slh_data_119 = prep.prep_slh_data_cmip6(data_type = 'ssp119')

# %%
slh_data_119
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 15, time: 86)>
# dask.array<concatenate, shape=(7, 15, 86), dtype=float64, chunksize=(1, 1, 86), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'CAMS-CSM1-0' 'CNRM-ESM2-1' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 1986-2005, including 20...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1
#     branching_method:   not_unsing_branching_time
#     detrending_order:   1

# %% [markdown]
# #### SSP126

# %%
slh_data_126 = prep.prep_slh_data_cmip6(data_type = 'ssp126')

# %%
slh_data_126
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 35, time: 86)>
# dask.array<concatenate, shape=(7, 35, 86), dtype=float64, chunksize=(1, 1, 86), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 1986-2005, including 20...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1
#     branching_method:   unsing_branching_time
#     detrending_order:   1

# %% [markdown]
# #### SSP245

# %%
slh_data_245 = prep.prep_slh_data_cmip6(data_type = 'ssp245')

# %%
slh_data_245
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 35, time: 86)>
# dask.array<concatenate, shape=(7, 35, 86), dtype=float64, chunksize=(1, 1, 86), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 1986-2005, including 20...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1
#     branching_method:   unsing_branching_time
#     detrending_order:   1

# %% [markdown]
# #### SSP370

# %%
slh_data_370 = prep.prep_slh_data_cmip6(data_type = 'ssp370')

# %%
slh_data_370
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 34, time: 86)>
# dask.array<concatenate, shape=(7, 34, 86), dtype=float64, chunksize=(1, 1, 86), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 1986-2005, including 20...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1
#     branching_method:   unsing_branching_time
#     detrending_order:   1

# %% [markdown]
# #### SSP585

# %%
slh_data_585 = prep.prep_slh_data_cmip6(data_type = 'ssp585')

# %%
slh_data_585
# Out:
# <xarray.DataArray 'zos' (station: 7, model: 38, time: 86)>
# dask.array<concatenate, shape=(7, 38, 86), dtype=float64, chunksize=(1, 1, 86), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * station  (station) <U15 'Vlissingen' 'Hoek v. Holland' ... 'Average'
# Attributes:
#     units:              cm
#     long_name:          Ocean dynamic sea level
#     ref_period:         The folowing reference period 1986-2005, including 20...
#     regridding_method:  xESMF package with bilinear
#     variant:            r1i1p1f1
#     branching_method:   unsing_branching_time
#     detrending_order:   1

# %% [markdown]
# # Import CMIP6 wind data and store as a netcdf file
#
# This second part of the notebook has the aim to process cmip6 wind data and save it as one dataset that is ready to be used for the regression analysis.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/Wind_contribution/Data preparation/code')

import prepare_data as prep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Historic

# %%
wind_data_hist = prep.prep_wind_data_cmip6()

# %%
wind_data_hist
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 43, time: 165, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 165, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 165, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  historical
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:52

# %%
wind_data_hist.u2
# Out:
# <xarray.DataArray 'u2' (model: 43, time: 165, lat: 50, lon: 70)>
# dask.array<mul, shape=(43, 165, 50, 70), dtype=float64, chunksize=(1, 165, 50, 70), chunktype=numpy.ndarray>
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5

# %% [markdown]
# #### piControl

# %%
wind_data_pico = prep.prep_wind_data_cmip6(data_type = 'piControl')

# %%
wind_data_pico.u2
# Out:
# <xarray.DataArray 'u2' (model: 44, time: 2000, lat: 30, lon: 60)>
# dask.array<concatenate, shape=(44, 2000, 30, 60), dtype=float64, chunksize=(1, 2000, 30, 60), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) float64 0.0 1.0 2.0 3.0 ... 1.997e+03 1.998e+03 1.999e+03
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 65.5 66.5 67.5 68.5 69.5
#   * lon      (lon) float64 -29.5 -28.5 -27.5 -26.5 -25.5 ... 26.5 27.5 28.5 29.5

# %% [markdown]
# #### SSP119

# %%
wind_data_119 = prep.prep_wind_data_cmip6(data_type = 'ssp119')

# %%
wind_data_119
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 14, time: 86, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'CAMS-CSM1-0' 'CNRM-ESM2-1' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp119
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:53

# %% [markdown]
# #### SSP126

# %%
wind_data_126 = prep.prep_wind_data_cmip6(data_type = 'ssp126')

# %%
wind_data_126
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 34, time: 86, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp126
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 09:53

# %% [markdown]
# #### SSP245

# %%
wind_data_245 = prep.prep_wind_data_cmip6(data_type = 'ssp245')

# %%
wind_data_245
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 34, time: 86, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp245
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 10:23

# %% [markdown]
# #### SSP370

# %%
wind_data_370 = prep.prep_wind_data_cmip6(data_type = 'ssp370')

# %%
wind_data_370
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 33, time: 86, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp370
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 10:24

# %% [markdown]
# #### SSP585

# %%
wind_data_585 = prep.prep_wind_data_cmip6(data_type = 'ssp585')

# %%
wind_data_585
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 35, time: 86, lat: 50, lon: 70)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 40.5 41.5 42.5 43.5 44.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -39.5 -38.5 -37.5 -36.5 -35.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     u2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
#     v2       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 50, 70), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp585
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-24 10:30

# %% [markdown]
# # Import CMIP6 pressure data and store as a netcdf file
#
# This second part of the notebook has the aim to process cmip6 wind data and save it as one dataset that is ready to be used for the regression analysis.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/Wind_contribution/Data preparation/code')

import prepare_data as prep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Historic

# %%
pres_data_hist = prep.prep_pres_data_cmip6()
# Out:
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1232: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]

# %%
pres_data_hist
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 56, time: 165, lat: 90, lon: 180)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014
#   * lat      (lat) float64 0.5 1.5 2.5 3.5 4.5 5.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     ps       (model, time, lat, lon) float64 dask.array<chunksize=(1, 165, 90, 180), meta=np.ndarray>
# Attributes:
#     emission_scenario:  historical
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-17 16:57

# %% [markdown]
# #### piControl

# %%
#pres_data_pico = prep.prep_pres_data_cmip6(data_type = 'piControl')

# %%
#pres_data_pico

# %% [markdown]
# #### SSP119

# %%
pres_data_119 = prep.prep_pres_data_cmip6(data_type = 'ssp119')

# %%
pres_data_119
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 15, time: 86, lat: 90, lon: 180)
# Coordinates:
#   * model    (model) object 'CAMS-CSM1-0' 'CNRM-ESM2-1' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 0.5 1.5 2.5 3.5 4.5 5.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     ps       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 90, 180), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp119
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-17 21:51

# %% [markdown]
# #### SSP126

# %%
pres_data_126 = prep.prep_pres_data_cmip6(data_type = 'ssp126')
# Out:
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1232: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]

# %%
pres_data_126
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 41, time: 86, lat: 90, lon: 180)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 0.5 1.5 2.5 3.5 4.5 5.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     ps       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 90, 180), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp126
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-17 22:02

# %% [markdown]
# #### SSP245

# %%
pres_data_245 = prep.prep_pres_data_cmip6(data_type = 'ssp245')
# Out:
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1232: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]

# %%
pres_data_245
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 42, time: 86, lat: 90, lon: 180)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 0.5 1.5 2.5 3.5 4.5 5.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     ps       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 90, 180), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp245
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-18 20:20

# %% [markdown]
# #### SSP370

# %%
pres_data_370 = prep.prep_pres_data_cmip6(data_type = 'ssp370')
# Out:
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1232: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]

# %%
pres_data_370
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 38, time: 86, lat: 90, lon: 180)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 0.5 1.5 2.5 3.5 4.5 5.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     ps       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 90, 180), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp370
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-18 22:00

# %% [markdown]
# #### SSP585

# %%
pres_data_585 = prep.prep_pres_data_cmip6(data_type = 'ssp585')
# Out:
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1232: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]

# %%
pres_data_585
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 43, time: 86, lat: 90, lon: 180)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100
#   * lat      (lat) float64 0.5 1.5 2.5 3.5 4.5 5.5 ... 85.5 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     ps       (model, time, lat, lon) float64 dask.array<chunksize=(1, 86, 90, 180), meta=np.ndarray>
# Attributes:
#     emission_scenario:  ssp585
#     source_file:        This NetCDF file was built from PreparePlaneVariables.py
#     creation_date:      2021-09-18 22:06
