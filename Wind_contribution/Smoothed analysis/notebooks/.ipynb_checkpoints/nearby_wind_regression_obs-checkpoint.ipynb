# %% [markdown]
# # SMOOTHED regression between sea level height and the nearest wind stress data point for observational data
#
# This regression can either be performed using observational or model (cmip6) data.
# When observational or cmip6 data is used, functions containing respectively 'obs' or 'cmip6' should be used.
#
# The regression is performed using smoothed time series and only for the Average station
#
# For each sea level datapoint, a wind stress data point located nearest to the sea level point is used to perform a regression.
#
# In this notebook, functions are used from:
#
# '/code/import_data.py'
#
# '/code/regression.py'
#
# '/code/figures.py'

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/Wind_contribution/Analysis/code')

import import_data as imprt
import regression as regres
import figures as figs

data_type = 'era5'
model = 'NearestPoint'

# %% [markdown]
# #### Import and plot tide gauge data

# %%
# Open data file
tg_data = imprt.import_obs_slh_data()

# %%
figs.plot_tg_data(tg_data)

# %% [markdown]
# #### Import and plot nearby wind data

# %%
wind_data_era5 = imprt.import_obs_wind_data(model = model, data_type = data_type)

# %%
wind_data_era5
# Out:
#      Vlissingen Hoek v. Holland Den Helder  Delfzijl  Harlingen   IJmuiden  \
#           u$^2$           u$^2$      u$^2$     u$^2$      u$^2$      u$^2$
# time
# 1950   4.733644        6.345675   9.164554  2.814705   7.602190   7.574831
# 1951   2.215220        3.094227   5.129766  1.345894   4.254703   3.909268
# 1952   3.140214        4.201388   7.262647  2.741641   6.585569   5.366155
# 1953   2.692977        3.829823   6.808114  2.271224   5.938963   4.985612
# 1954   8.065403       10.580028  14.525902  3.746828  11.332446  12.414601
# ...         ...             ...        ...       ...        ...        ...
# 2016   2.870005        3.364094   4.651558  1.689992   4.181081   3.813334
# 2017   5.444768        7.589746  12.106847  3.815765   9.986858   9.524419
# 2018   1.602232        2.100673   3.076977  0.659114   2.464558   2.539731
# 2019   3.602367        4.845805   7.729710  2.707826   6.395590   6.055294
# 2020   5.776422        7.739346  11.028156  3.406914   8.683282   9.163976
#
#         Average Vlissingen Hoek v. Holland Den Helder  Delfzijl Harlingen  \
#           u$^2$      v$^2$           v$^2$      v$^2$     v$^2$     v$^2$
# time
# 1950   6.372600   2.731458        3.180596   3.728501  1.950656  3.185383
# 1951   3.324846   4.189133        4.875644   6.217201  2.589350  4.982398
# 1952   4.882936   0.754191        0.748247   0.540864  0.799019  0.620607
# 1953   4.421119   1.657496        1.953852   2.634877  1.285330  2.170539
# 1954  10.110868   1.852473        2.051144   2.859851  2.389015  2.856825
# ...         ...        ...             ...        ...       ...       ...
# 2016   3.428344   1.896073        2.166514   2.891788  1.476865  2.518330
# 2017   8.078067   1.284091        1.384115   1.738423  1.651508  1.608859
# 2018   2.073881   0.977326        1.164025   2.088773  1.048094  1.724187
# 2019   5.222765   2.800420        3.304794   4.349144  2.296190  3.925604
# 2020   7.633016   4.740236        5.581194   6.544143  3.660878  5.995331
#
#       IJmuiden   Average
#          v$^2$     v$^2$
# time
# 1950  3.380980  3.026262
# 1951  5.261225  4.685825
# 1952  0.670609  0.688923
# 1953  2.212620  1.985786
# 1954  2.352618  2.393654
# ...        ...       ...
# 2016  2.388465  2.223006
# 2017  1.481535  1.524755
# 2018  1.343516  1.390987
# 2019  3.700750  3.396150
# 2020  5.948149  5.411655
#
# [71 rows x 14 columns]

# %%
figs.plot_obs_wind_data(wind_data_era5, model, data_type = data_type)

# %% [markdown]
# ### Perform regression

# %%
results_era5, timeseries_era5, significance_era5 = regres.regression_obs(wind_data_era5, tg_data, wind_model = model, data_type = data_type)

# %%
results_era5
# Out:
#                     R$^2$  R$^2_{wind}$  R$^2_{u^2}$  R$^2_{v^2}$      RMSE  \
# station
# Vlissingen       0.775638      0.072730     0.094883     0.090925  2.421130
# Hoek v. Holland  0.893355      0.092681     0.143101     0.076198  2.177621
# Den Helder       0.811394      0.250261     0.269590     0.091908  2.245620
# Delfzijl         0.838186      0.217872     0.228322     0.133147  2.694132
# Harlingen        0.796707      0.332094     0.335212     0.112340  2.466595
# IJmuiden         0.766658      0.156741     0.173378     0.100078  2.511510
# Average          0.860022      0.189773     0.216121     0.105092  2.076996
#
#                  constant     u$^2$     v$^2$     trend
# station
# Vlissingen       7.348812  1.388541 -0.215580  4.285542
# Hoek v. Holland  9.960944  2.347732 -0.720891  5.971357
# Den Helder       6.357774  2.372538 -0.204809  3.881352
# Delfzijl         7.614678  2.821242 -0.147691  5.286768
# Harlingen        5.832838  2.879980 -0.037584  3.739484
# IJmuiden         7.142322  1.922333 -0.169479  4.064086
# Average          7.376228  2.310280 -0.286539  4.547929

# %%
timeseries_era5
# Out:
#      Vlissingen                                          Hoek v. Holland  \
#           u$^2$     v$^2$     trend     total wind total           u$^2$
# time
# 1950   0.578919 -0.151827 -7.318957 -6.891864   0.427092        1.076738
# 1951  -1.244648 -0.368040 -7.109843 -8.722532  -1.612688       -1.877205
# 1952  -0.574869  0.141455 -6.900730 -7.334144  -0.433414       -0.871348
# 1953  -0.898709  0.007470 -6.691617 -7.582856  -0.891238       -1.208915
# 1954   2.991415 -0.021450 -6.482504 -3.512540   2.969965        4.923651
# ...         ...       ...       ...       ...        ...             ...
# 2016  -0.770525 -0.027917  6.482504  5.684063  -0.798442       -1.632031
# 2017   1.093838  0.062857  6.691617  7.848312   1.156694        2.206978
# 2018  -1.688507  0.108358  6.900730  5.320582  -1.580149       -2.779849
# 2019  -0.240228 -0.162056  7.109843  6.707559  -0.402284       -0.285895
# 2020   1.333985 -0.449783  7.318957  8.203158   0.884201        2.342889
#
#                                                  ...  IJmuiden            \
#          v$^2$      trend      total wind total  ...     u$^2$     v$^2$
# time                                             ...
# 1950 -0.518181 -10.198034  -9.639477   0.558557  ...  0.890523 -0.113304
# 1951 -1.208659  -9.906662 -12.992526  -3.085864  ... -1.374021 -0.276640
# 1952  0.472636  -9.615289 -10.014002  -0.398712  ... -0.473972  0.122145
# 1953 -0.018467  -9.323917 -10.551299  -1.227382  ... -0.709067 -0.011809
# 1954 -0.058099  -9.032545  -4.166992   4.865552  ...  3.880480 -0.023971
# ...        ...        ...        ...        ...  ...       ...       ...
# 2016 -0.105095   9.032545   7.295419  -1.737125  ... -1.433288 -0.027085
# 2017  0.213615   9.323917  11.744510   2.420593  ...  2.094957  0.051700
# 2018  0.303269   9.615289   7.138709  -2.476580  ... -2.220106  0.063690
# 2019 -0.568773   9.906662   9.051994  -0.854668  ... -0.048230 -0.141082
# 2020 -1.496064  10.198034  11.044859   0.846825  ...  1.872279 -0.336313
#
#                                       Average                                \
#          trend     total wind total     u$^2$     v$^2$     trend     total
# time
# 1950 -6.940748 -6.163529   0.777219  1.024746 -0.176425 -7.767067 -6.918746
# 1951 -6.742441 -8.393102  -1.650661 -1.657991 -0.456192 -7.545151 -9.659333
# 1952 -6.544134 -6.895961  -0.351828 -0.286507  0.217600 -7.323235 -7.392142
# 1953 -6.345827 -7.066703  -0.720876 -0.693014 -0.001023 -7.101318 -7.795356
# 1954 -6.147520 -2.291010   3.856509  4.315297 -0.069781 -6.879402 -2.633887
# ...        ...       ...        ...       ...       ...       ...       ...
# 2016  6.147520  4.687147  -1.460373 -1.566889 -0.041014  6.879402  5.271500
# 2017  6.345827  8.492484   2.146657  2.525956  0.076696  7.101318  9.703971
# 2018  6.544134  4.387717  -2.156416 -2.759133  0.099247  7.323235  4.663348
# 2019  6.742441  6.553128  -0.189312  0.012622 -0.238781  7.545151  7.318993
# 2020  6.940748  8.476714   1.535966  2.134207 -0.578551  7.767067  9.322723
#
#
#      wind total
# time
# 1950   0.848321
# 1951  -2.114183
# 1952  -0.068907
# 1953  -0.694037
# 1954   4.245516
# ...         ...
# 2016  -1.607902
# 2017   2.602653
# 2018  -2.659886
# 2019  -0.226158
# 2020   1.555656
#
# [71 rows x 35 columns]

# %%
significance_era5
# Out:
#                          Vlissingen  Hoek v. Holland  Den Helder  Delfzijl  \
# reggression_contributor
# u$^2$                          True             True        True      True
# v$^2$                          True             True        True      True
# trend                          True             True        True      True
# total                          True             True        True      True
# wind total                     True             True        True      True
#
#                          Harlingen  IJmuiden  Average
# reggression_contributor
# u$^2$                         True      True     True
# v$^2$                         True      True     True
# trend                         True      True     True
# total                         True      True     True
# wind total                    True      True     True

# %% [markdown]
# #### Plot regression results

# %%
figs.plot_obs_result_per_station(results_era5, 'R$^2$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_era5, 'R$^2_{wind}$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_era5,'R$^2_{u^2}$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_era5, 'R$^2_{v^2}$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_era5, 'RMSE', model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_era5, ['wind total'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_era5, ['u$^2$', 'v$^2$'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_era5, ['u$^2$', 'v$^2$', 'trend', 'total'], model, data_type)

# %% [markdown]
# #### Plot trends

# %%
figs.plot_obs_trends_timeseries_per_station(tg_data, timeseries_era5, ['total', 'wind total', 'u$^2$', 'v$^2$', 'trend'], model, data_type)

# %%
figs.plot_obs_decadal_trends_timeseries_per_station(tg_data, timeseries_era5, ['total', 'wind total', 'u$^2$', 'v$^2$'], 30, model, data_type, errorbar = False)

# %% [markdown]
# ## 20cr observational data

# %%
data_type = '20cr'

# %% [markdown]
# #### Import and plot tide gauge data

# %%
# Open data file
tg_data = imprt.import_obs_slh_data(data_type = data_type)

# %%
figs.plot_tg_data(tg_data)

# %% [markdown]
# #### Import and plot nearby wind data

# %%
wind_data_20cr = imprt.import_obs_wind_data(model = model, data_type = data_type)

# %%
wind_data_20cr
# Out:
#      Vlissingen Hoek v. Holland Den Helder  Delfzijl  Harlingen  IJmuiden  \
#           u$^2$           u$^2$      u$^2$     u$^2$      u$^2$     u$^2$
# time
# 1836   4.280736        6.584667   6.910478  3.727988   6.910478  4.516213
# 1837   1.353248        2.056189   2.076946  1.076460   2.076946  1.381128
# 1838   1.357986       -0.019153  -0.999386  0.330283  -0.999386  0.568622
# 1839   1.817033        2.099380   1.256711  0.643964   1.256711  1.390687
# 1840   3.037146        5.090846   6.790268  4.106853   6.790268  3.778630
# ...         ...             ...        ...       ...        ...       ...
# 2011   3.357691        7.801598  10.394631  4.502903  10.394631  4.635073
# 2012   3.146897        6.454442   8.370232  3.828953   8.370232  3.846449
# 2013   1.069191        2.099496   2.678315  1.157905   2.678315  1.237018
# 2014   1.893830        4.477061   5.439456  1.995874   5.439456  2.221001
# 2015   4.347267        9.990269  14.162627  7.121828  14.162627  6.514071
#
#        Average Vlissingen Hoek v. Holland Den Helder  Delfzijl  Harlingen  \
#          u$^2$      v$^2$           v$^2$      v$^2$     v$^2$      v$^2$
# time
# 1836  5.488427   2.079730        1.016261   0.396981  1.251174   0.396981
# 1837  1.670153   1.122225        1.440843   1.660021  1.087890   1.660021
# 1838  0.039828   0.384786       -0.146213  -0.360937  0.324903  -0.360937
# 1839  1.410748   1.244798        1.163936   1.244915  0.949601   1.244915
# 1840  4.932335   0.997329        0.042540  -0.715971  0.764537  -0.715971
# ...        ...        ...             ...        ...       ...        ...
# 2011  6.847754   2.739325        3.458502   3.940963  2.823585   3.940963
# 2012  5.669534   2.953365        3.146500   2.973744  2.748808   2.973744
# 2013  1.820040   2.341691        3.192516   3.457477  2.232374   3.457477
# 2014  3.577780   5.854098        9.432332  10.517715  5.038972  10.517715
# 2015  9.383115   3.773011        5.040648   4.963057  3.093839   4.963057
#
#       IJmuiden   Average
#          v$^2$     v$^2$
# time
# 1836  1.418657  1.093297
# 1837  1.043204  1.335701
# 1838  0.185538  0.004523
# 1839  0.941078  1.131540
# 1840  0.632816  0.167546
# ...        ...       ...
# 2011  2.581144  3.247414
# 2012  2.743556  2.923286
# 2013  2.353057  2.839098
# 2014  5.943099  7.883989
# 2015  3.599095  4.238784
#
# [180 rows x 14 columns]

# %%
figs.plot_obs_wind_data(wind_data_20cr, model=model, data_type = data_type)

# %% [markdown]
# ### Perform regression

# %%
results_20cr, timeseries_20cr, significance_20cr = regres.regression_obs(wind_data_20cr, tg_data, wind_model = model, data_type = data_type)

# %%
results_20cr
# Out:
#                     R$^2$  R$^2_{wind}$  R$^2_{u^2}$  R$^2_{v^2}$      RMSE  \
# station
# Vlissingen       0.904442      0.071315     0.060772     0.000055  2.726730
# Hoek v. Holland  0.931613      0.200370     0.194841     0.002488  2.500945
# Den Helder       0.860689      0.354057     0.350760     0.001550  2.484439
# Delfzijl         0.889736      0.316746     0.317075     0.023983  2.776026
# Harlingen        0.842974      0.435231     0.436653     0.011700  2.479065
# IJmuiden         0.881470      0.180352     0.179646     0.007266  3.033232
# Average          0.927062      0.276268     0.273593     0.004753  2.125666
#
#                  constant     u$^2$     v$^2$      trend
# station
# Vlissingen      -5.755461  1.316336 -0.464697  11.646055
# Hoek v. Holland -4.055133  1.927236 -0.207581  12.229507
# Den Helder      -2.731276  2.233327 -0.199408   7.243911
# Delfzijl        -4.195915  2.582991  0.210425   9.511788
# Harlingen       -2.192713  2.661063  0.148255   6.097163
# IJmuiden        -5.723784  1.666645 -0.032244  10.980625
# Average         -4.094373  2.092668 -0.121010   9.574456

# %%
timeseries_20cr
# Out:
#      Vlissingen                                            Hoek v. Holland  \
#           u$^2$     v$^2$      trend      total wind total           u$^2$
# time
# 1836   1.794531  0.037449 -20.059804 -18.227824   1.831980        1.155567
# 1837  -1.266885  0.389136 -19.835672 -20.713421  -0.877749       -1.956727
# 1838  -1.261930  0.659994 -19.611540 -20.213476  -0.601936       -3.383050
# 1839  -0.781883  0.344116 -19.387409 -19.825176  -0.437767       -1.927043
# 1840   0.494049  0.435010 -19.163277 -18.234218   0.929059        0.128906
# ...         ...       ...        ...        ...        ...             ...
# 2011   0.829258 -0.204817  19.163277  19.787717   0.624441        1.991929
# 2012   0.608821 -0.283433  19.387409  19.712796   0.325388        1.066067
# 2013  -1.563937 -0.058768  19.611540  17.988835  -1.622705       -1.926963
# 2014  -0.701573 -1.348859  19.835672  17.785240  -2.050432       -0.292930
# 2015   1.864106 -0.584485  20.059804  21.339425   1.279620        3.496140
#
#                                                  ...  IJmuiden            \
#          v$^2$      trend      total wind total  ...     u$^2$     v$^2$
# time                                             ...
# 1836  0.138142 -21.064775 -19.771065   1.293709  ...  1.323541  0.013688
# 1837  0.094549 -20.829414 -22.691592  -1.862178  ... -1.762387  0.023171
# 1838  0.257497 -20.594054 -23.719607  -3.125553  ... -2.562153  0.044833
# 1839  0.122980 -20.358693 -22.162756  -1.804063  ... -1.752978  0.025750
# 1840  0.238117 -20.123332 -19.756309   0.367024  ...  0.597523  0.033536
# ...        ...        ...        ...        ...  ...       ...       ...
# 2011 -0.112610  20.123332  22.002651   1.879319  ...  1.440537 -0.015673
# 2012 -0.080576  20.358693  21.344184   0.985491  ...  0.664279 -0.019775
# 2013 -0.085300  20.594054  18.581790  -2.012263  ... -1.904237 -0.009912
# 2014 -0.725961  20.829414  19.810523  -1.018891  ... -0.935683 -0.100586
# 2015 -0.275054  21.064775  24.285861   3.221087  ...  3.290073 -0.041383
#
#                                         Average                       \
#           trend      total wind total     u$^2$     v$^2$      trend
# time
# 1836 -18.913631 -17.576402   1.337229  1.030130  0.082763 -16.491568
# 1837 -18.702305 -20.441522  -1.739217 -2.300653  0.065044 -16.307305
# 1838 -18.490980 -21.008300  -2.517320 -3.722829  0.162348 -16.123042
# 1839 -18.279654 -20.006882  -1.727227 -2.526939  0.079968 -15.938778
# 1840 -18.068329 -17.437270   0.631059  0.545036  0.150432 -15.754515
# ...         ...        ...        ...       ...       ...        ...
# 2011  18.068329  19.493193   1.424864  2.215908 -0.074694  15.754515
# 2012  18.279654  18.924158   0.644504  1.188115 -0.051002  15.938778
# 2013  18.490980  16.576830  -1.914150 -2.169902 -0.044848  16.123042
# 2014  18.702305  17.666036  -1.036269 -0.636579 -0.413609  16.307305
# 2015  18.913631  22.162320   3.248689  4.427571 -0.147159  16.491568
#
#
#           total wind total
# time
# 1836 -15.378675   1.112893
# 1837 -18.542913  -2.235608
# 1838 -19.683523  -3.560481
# 1839 -18.385750  -2.446971
# 1840 -15.059047   0.695468
# ...         ...        ...
# 2011  17.895729   2.141214
# 2012  17.075892   1.137113
# 2013  13.908292  -2.214750
# 2014  15.257117  -1.050188
# 2015  20.771980   4.280412
#
# [180 rows x 35 columns]

# %%
significance_20cr
# Out:
#                          Vlissingen  Hoek v. Holland  Den Helder  Delfzijl  \
# reggression_contributor
# u$^2$                          True             True        True      True
# v$^2$                         False            False       False     False
# trend                          True             True        True      True
# total                          True             True        True      True
# wind total                     True             True        True      True
#
#                          Harlingen  IJmuiden  Average
# reggression_contributor
# u$^2$                         True      True     True
# v$^2$                        False     False    False
# trend                         True      True     True
# total                         True      True     True
# wind total                    True      True     True

# %% [markdown]
# #### Plot regression results

# %%
figs.plot_obs_result_per_station(results_20cr, 'R$^2$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_20cr, 'R$^2_{wind}$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_20cr,'R$^2_{u^2}$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_20cr, 'R$^2_{v^2}$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_20cr, 'RMSE', model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_20cr, ['wind total'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_20cr, ['u$^2$', 'v$^2$'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_20cr, ['u$^2$', 'v$^2$', 'trend', 'total'], model, data_type)

# %% [markdown]
# #### Plot trends

# %%
figs.plot_obs_trends_timeseries_per_station(tg_data, timeseries_20cr, ['total', 'wind total', 'u$^2$', 'v$^2$', 'trend'], model, data_type)

# %%
figs.plot_obs_decadal_trends_timeseries_per_station(tg_data, timeseries_20cr, ['total', 'wind total', 'u$^2$', 'v$^2$'], 30, model, data_type, errorbar = False)
