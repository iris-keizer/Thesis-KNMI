# %% [markdown]
# # Regression between sea level height and the timmerman wind data regions for observational data
#
# This regression can either be performed using observational or model (cmip6) data.
# When observational or cmip6 data is used, functions containing respectively 'obs' or 'cmip6' should be used.
#
#
# For each sea level datapoint, a wind stress data point located nearest to the sea level point to perform a regression.
#
# In this notebook, functions are used from:
#
# '/code/import_data.py'
#
# '/code/regression.py'
#
# '/code/figures.py'

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/Wind_contribution/Analysis/code')

import import_data as imprt
import regression as regres
import figures as figs


data_type = 'era5'
model = 'Timmerman'

# %% [markdown]
# #### Plot Timmerman regions

# %%
# Function that creates plot of the Timmerman regions
def timmerman_regions_plot(saveplots):
    
    plt.figure(figsize=(15, 10))

    # choose a good projection for regional maps
    proj = ccrs.LambertConformal(central_longitude=0)
    
    # do the plot
    ax = Timmerman_regions.plot(add_ocean=True, resolution="50m", proj=proj, label="name")
    
    # fine tune the extent
    ax.set_extent([-7, 10, 47, 61], crs=ccrs.PlateCarree())
    
    if saveplots:
        plt.savefig('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/ERA5/Figures/Timmerman/Timmerman_regions.png')

# %%
def timmerman_regions():
    

    # As first coordinates take most South-West point and than go anti-clockwise
    Channel = np.array([[-5.1, 48.6], [1.5, 50.1], [1.5, 50.9], [-5.1, 49.9]])
    South = np.array([[0.5, 50.8], [3.2, 51.3], [5.3, 53.1], [1.7, 52.3]])
    Mid_West = np.array([[1.7, 52.3], [5.3, 53.1], [3.7, 55.7], [-1.3, 55.1], [0.5, 53.1], [1.8, 52.7]])
    Mid_East = np.array([[5.3, 53.1], [8.9, 53.9], [7.8, 57.0], [3.7, 55.7]])
    North_West = np.array([[-1.3, 55.1], [3.7, 55.7], [1.1, 59.3], [-3.0, 58.7], [-1.7, 57.5], [-1.5, 55.5]])
    North_East = np.array([[3.7, 55.7], [7.8, 57.0], [7.4, 58.0], [6.1, 58.6], [4.9, 60.3], [1.1, 59.3]])

    region_names = ["Channel", "South", "Mid-West", "Mid-East", "North-West", "North-East"]
    region_abbrevs = ["C", "S", "MW", "ME", "NW", "NE"]
    region_numbers = [1,2,3,4,5,6]
    Timmerman_regions = regionmask.Regions([Channel, South, Mid_West, Mid_East, North_West, North_East], numbers = region_numbers, 
                                           names=region_names, abbrevs=region_abbrevs, name="Timmerman")
    
    return Timmerman_regions

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import regionmask

fig = plt.figure(figsize=(8,16))
ax = plt.axes(projection=ccrs.PlateCarree())
timmerman_regions().plot(add_ocean=True, resolution="50m", proj=ccrs.PlateCarree(), label="name")
ax.set_extent([-7, 10, 47, 61], ccrs.PlateCarree())

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cf
import numpy as np
import regionmask

fig = plt.figure(figsize=(6,9))
ax = plt.axes(projection=ccrs.LambertConformal(central_longitude=0))
timmerman_regions().plot(add_ocean=True, resolution="50m", proj=ccrs.LambertConformal(central_longitude=0), label="name")
ax.set_extent([-7, 10, 47, 61], ccrs.PlateCarree())

# %%
figs.timmerman_regions_plot()

# %% [markdown]
# #### Import and plot tide gauge data

# %%
# Open data file
tg_data = imprt.import_obs_slh_data()

# %%
figs.plot_tg_data(tg_data)

# %% [markdown]
# #### Import and plot nearby wind data

# %%
wind_data_era5 = imprt.import_obs_wind_data(model = model, data_type = data_type)

# %%
wind_data_era5
# Out:
#         Channel                South             Mid-West            \
#           u$^2$     v$^2$      u$^2$     v$^2$      u$^2$     v$^2$
# time
# 1950  12.316069  2.160256   8.262183  4.041305   8.584405  4.609705
# 1951   9.091509  3.399517   4.721186  6.609374   6.462471  7.438522
# 1952   7.544790 -0.726687   5.772462  0.936855   7.444201 -0.193246
# 1953   4.353734  0.893492   5.077993  2.553824   7.646784  3.443362
# 1954  13.225689  0.533389  13.136430  2.714039  13.472046  3.240453
# ...         ...       ...        ...       ...        ...       ...
# 2016   7.010372  1.776007   4.492962  3.094546   5.532615  3.626648
# 2017  11.630273  0.406660  10.108109  2.040739  13.155661  2.520331
# 2018   5.153245  1.826134   3.098964  2.625134   4.536352  4.291521
# 2019   8.473024  1.723831   6.476494  4.163897   8.741339  4.177894
# 2020  12.528422  2.871880  10.073592  6.292929  12.320718  6.441253
#
#        Mid-East           North-West           North-East
#           u$^2$     v$^2$      u$^2$     v$^2$      u$^2$     v$^2$
# time
# 1950   8.101027  2.522368   7.013565  7.557420   3.966120  5.114803
# 1951   6.362149  5.580308   5.833830  9.635615   2.495143  9.697726
# 1952   8.791636 -0.327027   7.919094 -1.071391   5.063189  0.183969
# 1953   9.280859  2.147830   8.386577  5.926245   6.164338  4.168941
# 1954  10.562153  4.062375   8.128158  4.496390   3.436815  5.024040
# ...         ...       ...        ...       ...        ...       ...
# 2016   6.214812  2.229459   6.361533  4.413408   3.943893  3.580360
# 2017  14.493663  1.323550  13.115123  2.379122   9.857128  1.494243
# 2018   3.704020  2.986358   3.926987  7.248913   1.361824  5.408401
# 2019   9.809879  2.972926   6.251465  3.867711   3.540207  2.265945
# 2020  13.922107  5.687397  12.519497  7.455038  10.459797  5.902577
#
# [71 rows x 12 columns]

# %%
figs.plot_obs_wind_data(wind_data_era5, model = model, data_type = data_type)

# %% [markdown]
# ### Perform regression

# %%
results_era5, timeseries_era5, significance_era5 = regres.regression_obs(wind_data_era5, tg_data, wind_model = model, data_type = data_type)

# %%
results_era5
# Out:
#                     R$^2$  R$^2_{wind}$  R$^2_{u^2}$  R$^2_{v^2}$      RMSE  \
# station
# Vlissingen       0.842877      0.256000     0.316248     0.001177  2.026108
# Hoek v. Holland  0.918431      0.232352     0.292538     0.032301  1.904472
# Den Helder       0.832441      0.377549     0.376182     0.048176  2.116621
# Delfzijl         0.849681      0.318567     0.336812     0.000000  2.596682
# Harlingen        0.824710      0.473738     0.488294     0.000000  2.290419
# IJmuiden         0.803957      0.310913     0.314601     0.023385  2.302045
# Average          0.888467      0.337203     0.364767     0.002436  1.853986
#
#                  constant  Channel u$^2$  Channel v$^2$  South u$^2$  \
# station
# Vlissingen       7.348812       0.631251      -0.075549    -0.954999
# 2019           -0.0       0.848259           -0.0        -0.253389
# 2020           -0.0       3.187287           -0.0         1.082857
#
#                        ...   Average                                        \
#      North-West v$^2$  ...     trend      total wind total   Channel South
# time                   ...
# 1950        -0.871581  ... -7.116940  -7.150543  -0.033604  0.666347   0.0
# 1951        -1.504629  ... -6.913599  -8.448547  -1.534949  0.457510   0.0
# 1952         1.756881  ... -6.710257  -5.419536   1.290721 -0.205060   0.0
# 1953        -0.374701  ... -6.506916  -6.694639  -0.187722 -0.364812   0.0
# 1954         0.060853  ... -6.303575  -4.620898   1.682677  0.573088   0.0
# ...               ...  ...       ...        ...        ...       ...   ...
# 2016         0.086131  ...  6.303575   5.416636  -0.886939  0.034020   0.0
# 2017         0.705804  ...  6.506916  10.250973   3.744057  0.381616   0.0
# 2018        -0.777605  ...  6.710257   3.857510  -2.852748 -0.165315   0.0
# 2019         0.252358  ...  6.913599   8.004144   1.090546  0.189502   0.0
# 2020        -0.840393  ...  7.116940   9.820480   2.703540  0.774603   0.0
#
#
#      Mid-West  Mid-East North-West u$^2$ total v$^2$ total
# time
# 1950      0.0 -0.109941  -0.610879    0.474637   -0.508241
# 1951      0.0 -0.984308  -1.054574   -0.683376   -0.851573
# 1952      0.0  0.262598   1.231373    0.256595    1.034126
# 1953      0.0  0.457032  -0.262623    0.117389   -0.305111
# 1954      0.0  1.036874   0.042651    1.755016   -0.072338
# ...       ...       ...        ...         ...         ...
# 2016      0.0 -1.002582   0.060368   -1.008696    0.121757
# 2017      0.0  2.949224   0.494688    3.337112    0.406945
# 2018      0.0 -2.208532  -0.545012   -2.363394   -0.489354
# 2019      0.0  0.695902   0.176874    0.869993    0.220553
# 2020      0.0  2.609897  -0.589020    3.154075   -0.450535
#
# [71 rows x 154 columns]

# %%
significance_era5
# Out:
#                          Vlissingen  Hoek v. Holland  Den Helder  Delfzijl  \
# reggression_contributor
# Channel u$^2$                  True             True        True      True
# Channel v$^2$                  True             True        True      True
# South u$^2$                    True             True        True      True
# South v$^2$                    True             True        True      True
# Mid-West u$^2$                 True             True        True      True
# Mid-West v$^2$                 True             True        True      True
# Mid-East u$^2$                 True             True        True      True
# Mid-East v$^2$                False            False       False     False
# North-West u$^2$               True             True        True      True
# North-West v$^2$              False            False       False     False
# North-East u$^2$               True             True        True      True
# North-East v$^2$              False            False       False     False
# trend                          True             True        True      True
# total                          True             True        True      True
# wind total                     True             True        True      True
#
#                          Harlingen  IJmuiden  Average
# reggression_contributor
# Channel u$^2$                 True      True     True
# Channel v$^2$                 True      True     True
# South u$^2$                   True      True     True
# South v$^2$                   True      True     True
# Mid-West u$^2$                True      True     True
# Mid-West v$^2$                True      True     True
# Mid-East u$^2$                True      True     True
# Mid-East v$^2$                True     False    False
# North-West u$^2$              True      True     True
# North-West v$^2$             False     False    False
# North-East u$^2$              True      True     True
# North-East v$^2$             False     False    False
# trend                         True      True     True
# total                         True      True     True
# wind total                    True      True     True

# %% [markdown]
# #### Plot regression results

# %%
figs.plot_obs_result_per_station(results_era5, 'R$^2$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_era5, 'RMSE', model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_era5, ['wind total', 'total'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_era5, ['u$^2$ total', 'v$^2$ total'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_era5, ['u$^2$ total', 'v$^2$ total', 'trend', 'total'], model, data_type)

# %% [markdown]
# #### Plot trends

# %%
figs.plot_obs_trends_timeseries_per_station(tg_data, timeseries_era5, ['total', 'wind total', 'trend', 'u$^2$ total', 'v$^2$ total'], model, data_type)

# %%
figs.plot_obs_decadal_trends_timeseries_per_station(tg_data, timeseries_era5, ['total', 'wind total', 'u$^2$ total', 'v$^2$ total'], 30, model, data_type, errorbar = False)

# %% [markdown]
# ## 20cr observational data

# %%
data_type = '20cr'

# %% [markdown]
# #### Import and plot tide gauge data

# %%
# Open data file
tg_data = imprt.import_obs_slh_data(data_type = data_type)

# %%
figs.plot_tg_data(tg_data)

# %% [markdown]
# #### Import and plot nearby wind data

# %%
wind_data_20cr = imprt.import_obs_wind_data(model = model, data_type = data_type)

# %%
wind_data_20cr
# Out:
#         Channel                South             Mid-West             \
#           u$^2$     v$^2$      u$^2$     v$^2$      u$^2$      v$^2$
# time
# 1836   9.339661 -1.110606   6.401690  0.310869   6.692063  -1.423788
# 1837   3.264673  0.735447   2.035330  1.325370   3.044824   1.955889
# 1838   0.351915 -0.748255  -0.266823 -0.360828  -1.300336  -1.106671
# 1839   4.765925  0.554752   2.080075  0.976965   2.073684   1.277253
# 1840   0.849854 -0.191308   4.820944 -0.441465   6.431440  -1.902902
# ...         ...       ...        ...       ...        ...        ...
# 2011  10.742952  3.004566   8.155463  3.485028  13.435661   6.483733
# 2012   9.914115  1.996948   6.809952  2.736764  10.189938   1.982328
# 2013   3.260722  1.484737   2.263472  2.715020   5.177427   4.285154
# 2014  10.595210  6.510784   5.115736  9.385818   7.802488  13.314934
# 2015  10.741358  6.099349  10.573762  5.000158  17.265608   6.761311
#
#        Mid-East            North-West            North-East
#           u$^2$      v$^2$      u$^2$      v$^2$      u$^2$      v$^2$
# time
# 1836   5.914341  -0.938669   4.039640  -1.211254   2.221467  -1.732220
# 1837   1.566807   1.638099   2.953883   2.951589   0.155643   3.296363
# 1838  -1.807967  -0.944153  -0.071450   1.847939  -2.106020   0.592806
# 1839  -0.375581   1.146095   1.792541   3.554612  -1.421507   3.026562
# 1840   8.379648  -2.250757   6.112606  -2.001526   4.964725  -2.783268
# ...         ...        ...        ...        ...        ...        ...
# 2011  13.715880   5.262648  14.429358  11.633640  10.596898   9.564071
# 2012  10.420673   2.108283  10.758274   0.440513   6.598078   2.038419
# 2013   5.956827   3.209796   8.885650   7.610978   6.540488   5.776588
# 2014   5.428218  11.872807   7.111277  17.830263   0.915726  18.478556
# 2015  18.294571   4.461973  18.431528   9.313465  13.466646   8.660346
#
# [180 rows x 12 columns]

# %%
figs.plot_obs_wind_data(wind_data_20cr, model = model, data_type = data_type)

# %% [markdown]
# ### Perform regression

# %%
results_20cr, timeseries_20cr, significance_20cr = regres.regression_obs(wind_data_20cr, tg_data, wind_model = model, data_type = data_type)

# %%
results_20cr
# Out:
#                     R$^2$  R$^2_{wind}$  R$^2_{u^2}$  R$^2_{v^2}$      RMSE  \
# station
# Vlissingen       0.922830      0.341111     0.228307     0.114912  2.450376
# Hoek v. Holland  0.941802      0.308374     0.260919     0.091587  2.307124
# Den Helder       0.881525      0.421254     0.366123     0.116299  2.291126
# Delfzijl         0.904444      0.445219     0.369182     0.118316  2.584260
# Harlingen        0.862314      0.499320     0.452920     0.081144  2.321386
# IJmuiden         0.903382      0.324180     0.259839     0.109133  2.738547
# Average          0.944198      0.397175     0.310698     0.123367  1.859266
#
#                  constant  Channel u$^2$  Channel v$^2$  South u$^2$  \
# station
# Vlissingen      -5.439468      -0.000000       1.057138     0.256587
# Hoek v. Holland -3.923573       0.000000       0.667649     0.627935
# Den Helder      -2.665962      -0.000000       0.714852     0.000000
# Delfzijl        -3.980395      -0.000000       0.978166     0.193537
# Harlingen       -2.089775       0.000000       0.491637     0.906477
# IJmuiden        -5.544875      -0.000000       1.038997     0.000000
# Average         -3.991564       0.116727       1.117913     0.430016
#
#                  South v$^2$  Mid-West u$^2$  Mid-West v$^2$  Mid-East u$^2$  \
# station
# Vlissingen         -0.000000        0.531445       -1.210805        0.353253
# Hoek v. Holland    -0.000000        0.360460       -0.000000        0.376712
# Den Helder         -0.000000        0.669836       -0.000000        1.473125
# Delfzijl            0.000000        1.224395       -0.000000        0.000000
# Harlingen           0.000000        0.000000       -0.000000        0.895032
# IJmuiden           -0.000000        0.522981        0.000000        1.139503
# Average            -0.393842        0.241165       -0.000000        0.759156
#
#                  Mid-East v$^2$  North-West u$^2$  North-West v$^2$  \
# station
# Vlissingen                 -0.0          0.459395         -0.000000
# Hoek v. Holland            -0.0          0.625428         -0.596841
# Den Helder                 -0.0          0.094396         -0.607073
# Delfzijl                   -0.0          0.000000         -0.410050
# Harlingen                  -0.0          1.052731         -0.000000
# IJmuiden                    0.0          0.150738         -1.083587
# Average                     0.0          0.812123         -0.797995
#
#                  North-East u$^2$  North-East v$^2$      trend
# station
# Vlissingen               0.000000          0.000000  10.712959
# Hoek v. Holland          0.000000         -0.000000  11.681927
# Den Helder               0.000000         -0.000000   6.867984
# Delfzijl                 1.463367         -0.024428   8.741036
# Harlingen                0.011086         -0.000000   5.571453
# IJmuiden                 0.000000          0.152420  10.339164
# Average                  0.000000          0.174611   9.099762

# %%
timeseries_20cr['Average']
# Out:
#       Channel u$^2$  Channel v$^2$  South u$^2$  South v$^2$  Mid-West u$^2$  \
# time
# 1836       0.081314      -1.483377     0.217380     0.357548       -0.039030
# 1837      -0.081758      -0.295624    -0.447103     0.155306       -0.245297
# 1838      -0.159945      -1.250240    -0.797451     0.491452       -0.491034
# Den Helder                       False           True         True
# Delfzijl                         False           True         True
# Harlingen                        False           True         True
# IJmuiden                         False           True         True
# Average                          False           True         True
#
# reggression_contributor  South v$^2$  Mid-West u$^2$  Mid-West v$^2$  \
# Vlissingen                     False            True           False
# Hoek v. Holland                False            True           False
# Den Helder                     False            True           False
# Delfzijl                       False            True           False
# Harlingen                      False            True           False
# IJmuiden                       False            True           False
# Average                        False            True           False
#
# reggression_contributor  Mid-East u$^2$  Mid-East v$^2$  North-West u$^2$  \
# Vlissingen                         True           False              True
# Hoek v. Holland                    True           False              True
# Den Helder                         True           False              True
# Delfzijl                           True           False              True
# Harlingen                          True           False              True
# IJmuiden                           True           False              True
# Average                            True           False              True
#
# reggression_contributor  North-West v$^2$  North-East u$^2$  North-East v$^2$  \
# Vlissingen                          False              True             False
# Hoek v. Holland                     False              True             False
# Den Helder                          False              True             False
# Delfzijl                            False              True             False
# Harlingen                           False              True             False
# IJmuiden                            False              True             False
# Average                             False              True             False
#
# reggression_contributor  trend  total  wind total
# Vlissingen                True   True        True
# Hoek v. Holland           True   True        True
# Den Helder                True   True        True
# Delfzijl                  True   True        True
# Harlingen                 True   True        True
# IJmuiden                  True   True        True
# Average                   True   True        True

# %%
import xarray as xr
test = xr.Dataset.from_dataframe(significance_20cr.T).rename({'index':'station'})

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:           (station: 7)
# Coordinates:
#   * station           (station) object 'Vlissingen' ... 'Average'
# Data variables: (12/15)
#     Channel u$^2$     (station) bool False False False False False False False
#     Channel v$^2$     (station) bool True True True True True True True
#     South u$^2$       (station) bool True True True True True True True
#     South v$^2$       (station) bool False False False False False False False
#     Mid-West u$^2$    (station) bool True True True True True True True
#     Mid-West v$^2$    (station) bool False False False False False False False
#     ...                ...
#     North-West v$^2$  (station) bool False False False False False False False
#     North-East u$^2$  (station) bool True True True True True True True
#     North-East v$^2$  (station) bool False False False False False False False
#     trend             (station) bool True True True True True True True
#     total             (station) bool True True True True True True True
#     wind total        (station) bool True True True True True True True

# %% [markdown]
# #### Plot regression results

# %%
figs.plot_obs_result_per_station(results_20cr, 'R$^2$', model, data_type)

# %%
figs.plot_obs_result_per_station(results_20cr, 'RMSE', model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_20cr, ['wind total', 'total'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_20cr, ['u$^2$ total', 'v$^2$ total'], model, data_type)

# %%
figs.plot_obs_timeseries_per_station(tg_data, timeseries_20cr, ['u$^2$ total', 'v$^2$ total', 'trend', 'total'], model, data_type)

# %% [markdown]
# #### Plot trends

# %%
figs.plot_obs_trends_timeseries_per_station(tg_data, timeseries_20cr, ['total', 'wind total', 'trend', 'u$^2$ total', 'v$^2$ total'], model, data_type)

# %%
figs.plot_obs_decadal_trends_timeseries_per_station(tg_data, timeseries_20cr, ['total', 'wind total', 'u$^2$ total', 'v$^2$ total'], 30, model, data_type, errorbar = False)
