# %% [markdown]
# ## Notebook to prepare the cmip6 tos data for AMV regression
#
# This notebook has the aim to preparate the cmip6 tos data such that it can be used for both the regression between tos or AMV and atmospheric contribution to sea level change.
#
# The tos data is imported, all datasets for different models are joined, a subarea is selected, time values are changed to integers and variable names are updated.
#
# To obtain the amv records, tos data for the region ..X..°N and ..X..°S are selected.
# Detrending is applied by ..

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/Users/iriskeizer/Projects/ClimatePhysics/Thesis/Github/Thesis-KNMI/AMV/code')

import prepare_data as prep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tos_hist = prep.prep_tos_cmip6(data_type = 'historical')
tos_ssp119 = prep.prep_tos_cmip6(data_type = 'ssp119')
tos_ssp126 = prep.prep_tos_cmip6(data_type = 'ssp126')
tos_ssp245 = prep.prep_tos_cmip6(data_type = 'ssp245')
tos_ssp370 = prep.prep_tos_cmip6(data_type = 'ssp370')
tos_ssp585 = prep.prep_tos_cmip6(data_type = 'ssp585')

# %%
amv_hist = prep.prep_amv_cmip6(tos_hist)
amv_ssp119 = prep.prep_amv_cmip6(tos_ssp119, data_type = 'ssp119')
amv_ssp126 = prep.prep_amv_cmip6(tos_ssp126, data_type = 'ssp126')
amv_ssp245 = prep.prep_amv_cmip6(tos_ssp245, data_type = 'ssp245')
amv_ssp370 = prep.prep_amv_cmip6(tos_ssp370, data_type = 'ssp370')
amv_ssp585 = prep.prep_amv_cmip6(tos_ssp585, data_type = 'ssp585')

# %%
amv_hist.amv.plot(col='model', col_wrap = 4)

# %%
amv_hist = prep.prep_amv_cmip6(tos_hist)

# %%
amv_hist
# Out:
# <xarray.Dataset>
# Dimensions:  (model: 55, time: 165)
# Coordinates:
#   * model    (model) object 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
#   * time     (time) int64 1850 1851 1852 1853 1854 ... 2010 2011 2012 2013 2014
# Data variables:
#     amv      (model, time) float64 dask.array<mean_agg-aggregate, shape=(55, ...
